# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np
import pandas as pd
import os

# %%
train_path = '../data_to_model/keras_data/model_df_full_narrative.csv'
train_df = pd.read_csv(train_path)
train_df
# Out:
#       cpsc_case_number                                          narrative  \
# 0            100145411  67 yof pt fell on the floor playing pickle bal...
# 1            100417928  63yof playing pickleball in the hot sun and pa...
# 2            100417973       66yom strained lower leg playing pickle ball
# 3            100417997  60yof pt playing pickle ball and fell sustaine...
# 4            100454409  70 yom pt injured knee while playing pickle ba...
# ...                ...                                                ...
# 1986         200101825  68 yof tripped and fell while playing tennis. ...
# 1987         200102934  76yof was hit in the eye with a tennis ball dx...
# 1988         200110467  61yof was playing tennis when she developed pa...
# 1989         200124689  70yof fell while playing tennis dx: strained u...
# 1990         200301553  76yom.playing tennis slipped.fell down.dx.lac....
#
#          primary_mechanism
# 0       Falls, trips, etc.
# 1              Heat stroke
# 2          Other mechanism
# 3       Falls, trips, etc.
# 4          Other mechanism
# ...                    ...
# 1986    Falls, trips, etc.
# 1987  Hit with various obj
# 1988  Undetermined/unknown
# 1989    Falls, trips, etc.
# 1990    Falls, trips, etc.
#
# [1991 rows x 3 columns]

# %%
text_np = np.array(train_df['narrative'])
train_labels_np = np.array(train_df['primary_mechanism'])
#train_labels_np_bin = np.where(train_labels_np == 'Multi-sport', 'Multi-sport', 'Other')
print(train_labels_np[0:30])
#print(train_labels_np_bin[0:30])
# Out:
# ['Falls, trips, etc.' 'Heat stroke' 'Other mechanism' 'Falls, trips, etc.'
#  'Other mechanism' 'Falls, trips, etc.' 'Falls, trips, etc.'
#  'Other mechanism' 'Other mechanism' 'Falls, trips, etc.'
#  'Hit with various obj' 'Falls, trips, etc.' 'Falls, trips, etc.'
#  'cardio/sync' 'Falls, trips, etc.' 'Other mechanism' 'Other mechanism'
#  'Other mechanism' 'Other mechanism' 'Falls, trips, etc.'
#  'Falls, trips, etc.' 'Hit with various obj' 'Other mechanism'
#  'Multi-sport' 'Falls, trips, etc.' 'Other mechanism' 'Falls, trips, etc.'
#  'Falls, trips, etc.' 'Falls, trips, etc.' 'Falls, trips, etc.']

# %%
#l_list = []
#for txt in text_np:
#    l_list.append( len(txt) )
    
#l_list[0:10]

#max(l_list)

# %%
maxlen = 207
training_samples = 1491
validation_samples = 500
max_words = 100000
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(text_np)
sequences = tokenizer.texts_to_sequences(text_np)

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
data = pad_sequences(sequences, maxlen=maxlen)

print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', train_labels_np.shape)
# Out:
# Found 1857 unique tokens.
# Shape of data tensor: (1991, 207)
# Shape of label tensor: (1991,)

# %%
#indices = np.arange(data.shape[0])
#np.random.shuffle(indices)
#data = data[indices]
#train_labels_np = train_labels_np[indices]
#x_train = data[:training_samples]
#y_train = train_labels_np[:training_samples]
#x_val = data[training_samples: training_samples + validation_samples]
#y_val = train_labels_np[training_samples: training_samples + validation_samples]

# %%
label_encoder = LabelEncoder()

y_train_integer_encoded = label_encoder.fit_transform(train_labels_np)
#train_labels_npy_val_integer_encoded = label_encoder.fit_transform(y_val)

#y_train_integer_encoded
#y_train_integer_encodedtrain_labels_np
y_train_one_hot = to_categorical(y_train_integer_encoded, num_classes=7)
#y_val_one_hot = to_categorical(y_val_integer_encoded, num_classes=7)

# %%
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense
model = Sequential()
model.add(Embedding(max_words, 8, input_length=maxlen))
model.add(Flatten())
model.add(Dense(7, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 207, 8)            800000
# _________________________________________________________________
# flatten (Flatten)            (None, 1656)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 11599
# =================================================================
# Total params: 811,599
# Trainable params: 811,599
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(data, y_train_one_hot,
epochs=80,
batch_size=32,
validation_split=.15)
# Out:
# Epoch 1/80
# 53/53 [==============================] - 1s 12ms/step - loss: 0.3788 - accuracy: 0.4805 - val_loss: 0.3420 - val_accuracy: 0.4080
# Epoch 2/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.3204 - accuracy: 0.4976 - val_loss: 0.3390 - val_accuracy: 0.4080
# Epoch 3/80
# 53/53 [==============================] - 0s 9ms/step - loss: 0.3068 - accuracy: 0.4988 - val_loss: 0.3178 - val_accuracy: 0.4080
# Epoch 4/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2865 - accuracy: 0.5225 - val_loss: 0.2882 - val_accuracy: 0.5686
# Epoch 5/80
# 53/53 [==============================] - 0s 9ms/step - loss: 0.2644 - accuracy: 0.5632 - val_loss: 0.2659 - val_accuracy: 0.5753
# Epoch 6/80
# 53/53 [==============================] - 0s 9ms/step - loss: 0.2421 - accuracy: 0.6188 - val_loss: 0.2462 - val_accuracy: 0.6321
# Epoch 7/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2221 - accuracy: 0.6678 - val_loss: 0.2286 - val_accuracy: 0.6789
# Epoch 8/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2050 - accuracy: 0.7116 - val_loss: 0.2142 - val_accuracy: 0.6856
# Epoch 9/80
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1900 - accuracy: 0.7335 - val_loss: 0.2030 - val_accuracy: 0.7124
# Epoch 10/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1768 - accuracy: 0.7630 - val_loss: 0.1932 - val_accuracy: 0.7525
# Epoch 11/80
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1657 - accuracy: 0.7855 - val_loss: 0.1814 - val_accuracy: 0.7625
# Epoch 12/80
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1556 - accuracy: 0.8038 - val_loss: 0.1740 - val_accuracy: 0.7659
# Epoch 13/80
# 53/53 [==============================] - 0s 9ms/step - loss: 0.1461 - accuracy: 0.8191 - val_loss: 0.1673 - val_accuracy: 0.7726
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.1243 - val_accuracy: 0.8963
# Epoch 69/80
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0114 - accuracy: 0.9970 - val_loss: 0.1206 - val_accuracy: 0.8896
# Epoch 70/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.1213 - val_accuracy: 0.8896
# Epoch 71/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0103 - accuracy: 0.9982 - val_loss: 0.1233 - val_accuracy: 0.8930
# Epoch 72/80
# 53/53 [==============================] - 0s 9ms/step - loss: 0.0098 - accuracy: 0.9976 - val_loss: 0.1235 - val_accuracy: 0.8963
# Epoch 73/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.1237 - val_accuracy: 0.8997
# Epoch 74/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0088 - accuracy: 0.9982 - val_loss: 0.1258 - val_accuracy: 0.8997
# Epoch 75/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0084 - accuracy: 0.9988 - val_loss: 0.1215 - val_accuracy: 0.9030
# Epoch 76/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0080 - accuracy: 0.9988 - val_loss: 0.1280 - val_accuracy: 0.8963
# Epoch 77/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0076 - accuracy: 0.9988 - val_loss: 0.1281 - val_accuracy: 0.8930
# Epoch 78/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0072 - accuracy: 0.9988 - val_loss: 0.1297 - val_accuracy: 0.8896
# Epoch 79/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0068 - accuracy: 0.9988 - val_loss: 0.1267 - val_accuracy: 0.8930
# Epoch 80/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.0065 - accuracy: 0.9994 - val_loss: 0.1307 - val_accuracy: 0.8930

# %%
modelv2 = Sequential()
modelv2.add(Embedding(max_words, 8, input_length=maxlen))
modelv2.add(Flatten())
modelv2.add(Dense(64, activation='relu'))
modelv2.add(Dense(7, activation='sigmoid'))
modelv2.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
modelv2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 207, 8)            800000
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1656)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                106048
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 906,503
# Trainable params: 906,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2= modelv2.fit(data, y_train_one_hot,
epochs=80,
batch_size=32,
validation_split=.15)
# Out:
# Epoch 1/80
# 53/53 [==============================] - 1s 10ms/step - loss: 0.3690 - accuracy: 0.4805 - val_loss: 0.3446 - val_accuracy: 0.4080
# Epoch 2/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.3061 - accuracy: 0.5041 - val_loss: 0.3016 - val_accuracy: 0.5017
# Epoch 3/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2684 - accuracy: 0.5703 - val_loss: 0.2685 - val_accuracy: 0.5585
# Epoch 4/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2319 - accuracy: 0.6572 - val_loss: 0.2282 - val_accuracy: 0.7291
# Epoch 5/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.2056 - accuracy: 0.7222 - val_loss: 0.2088 - val_accuracy: 0.7324
# Epoch 6/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1840 - accuracy: 0.7465 - val_loss: 0.1999 - val_accuracy: 0.7358
# Epoch 7/80
# 53/53 [==============================] - 0s 8ms/step - loss: 0.1680 - accuracy: 0.7654 - val_loss: 0.1807 - val_accuracy: 0.7559
# 53/53 [==============================] - 0s 8ms/step - loss: 2.0307e-07 - accuracy: 1.0000 - val_loss: 0.3531 - val_accuracy: 0.8863
# Epoch 77/80
# 53/53 [==============================] - 0s 8ms/step - loss: 1.7209e-07 - accuracy: 1.0000 - val_loss: 0.3531 - val_accuracy: 0.8863
# Epoch 78/80
# 53/53 [==============================] - 0s 8ms/step - loss: 1.4811e-07 - accuracy: 1.0000 - val_loss: 0.3554 - val_accuracy: 0.8863
# Epoch 79/80
# 53/53 [==============================] - 0s 8ms/step - loss: 1.2699e-07 - accuracy: 1.0000 - val_loss: 0.3624 - val_accuracy: 0.8863
# Epoch 80/80
# 53/53 [==============================] - 0s 8ms/step - loss: 1.1280e-07 - accuracy: 1.0000 - val_loss: 0.3660 - val_accuracy: 0.8863

# %%
train_df
# Out:
#       cpsc_case_number                                          narrative  \
# 0            100145411  67 yof pt fell on the floor playing pickle bal...
# 1            100417928  63yof playing pickleball in the hot sun and pa...
# 2            100417973       66yom strained lower leg playing pickle ball
# 3            100417997  60yof pt playing pickle ball and fell sustaine...
# 4            100454409  70 yom pt injured knee while playing pickle ba...
# ...                ...                                                ...
# 1986         200101825  68 yof tripped and fell while playing tennis. ...
# 1987         200102934  76yof was hit in the eye with a tennis ball dx...
# 1988         200110467  61yof was playing tennis when she developed pa...
# 1989         200124689  70yof fell while playing tennis dx: strained u...
# 1990         200301553  76yom.playing tennis slipped.fell down.dx.lac....
#
#          primary_mechanism
# 0       Falls, trips, etc.
# 1              Heat stroke
# 2          Other mechanism
# 3       Falls, trips, etc.
# 4          Other mechanism
# ...                    ...
# 1986    Falls, trips, etc.
# 1987  Hit with various obj
# 1988  Undetermined/unknown
# 1989    Falls, trips, etc.
# 1990    Falls, trips, etc.
#
# [1991 rows x 3 columns]

# %%
model.save_weights('../Model Objects/keras_outv2.h5')

# %%
def getModel():
    my_dim = 8
    
    model = Sequential()
    model.add(Embedding(max_words, my_dim, input_length=maxlen))
    model.add(Flatten())
#    model.add(Dense(32, activation='relu'))
    model.add(Dense(7, activation='softmax'))
    
    return model

# %%
# Different configurations to try
epochs_list = [30, 60, 90]
batch_sizes = [16, 32, 64]
#embedding_dim = 8
# Dictionary to store the history of each configuration
history_dict = {}

for epochs in epochs_list:
    for batch_size in batch_sizes:
        # Get a fresh instance of the model for each run
        model = getModel()

        # Compile the model
        model.compile(optimizer='rmsprop',
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

        # Train the model
        history = model.fit(x_train, y_train_one_hot,
                            epochs=epochs,
                            batch_size=batch_size,
                            validation_data=(x_val, y_val_one_hot),
                            verbose=2)  # Set verbose to 2 for less output

        # Save the history of this configuration
        history_dict[f"epochs_{epochs}_batch_{batch_size}"] = history.history

        # Optionally, you can print out the final validation accuracy for each configuration
        final_val_accuracy = history.history['val_accuracy'][-1]
        print(f"Epochs: {epochs}, Batch size: {batch_size}, Validation accuracy: {final_val_accuracy}")

# Now you can analyze the history_dict to see which configuration performed best

# %%
history_dict
