# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np
import pandas as pd
import os

# %%
train_path = '../data_to_model/keras_data/model_df_full_narrative.csv'
train_df = pd.read_csv(train_path)
train_df
# Out:
#       cpsc_case_number                                          narrative  \
# 0            100145411  67 yof pt fell on the floor playing pickle bal...
# 1            100417928  63yof playing pickleball in the hot sun and pa...
# 2            100417973       66yom strained lower leg playing pickle ball
# 3            100417997  60yof pt playing pickle ball and fell sustaine...
# 4            100454409  70 yom pt injured knee while playing pickle ba...
# ...                ...                                                ...
# 1986         200101825  68 yof tripped and fell while playing tennis. ...
# 1987         200102934  76yof was hit in the eye with a tennis ball dx...
# 1988         200110467  61yof was playing tennis when she developed pa...
# 1989         200124689  70yof fell while playing tennis dx: strained u...
# 1990         200301553  76yom.playing tennis slipped.fell down.dx.lac....
#
#          primary_mechanism
# 0       Falls, trips, etc.
# 1              Heat stroke
# 2          Other mechanism
# 3       Falls, trips, etc.
# 4          Other mechanism
# ...                    ...
# 1986    Falls, trips, etc.
# 1987  Hit with various obj
# 1988  Undetermined/unknown
# 1989    Falls, trips, etc.
# 1990    Falls, trips, etc.
#
# [1991 rows x 3 columns]

# %%
text_np = np.array(train_df['narrative'])
train_labels_np = np.array(train_df['primary_mechanism'])
train_labels_np_bin = np.where(train_labels_np == 'Multi-sport', 'Multi-sport', 'Other')
print(train_labels_np[0:30])
print(train_labels_np_bin[0:30])
# Out:
# ['Falls, trips, etc.' 'Heat stroke' 'Other mechanism' 'Falls, trips, etc.'
#  'Other mechanism' 'Falls, trips, etc.' 'Falls, trips, etc.'
#  'Other mechanism' 'Other mechanism' 'Falls, trips, etc.'
#  'Hit with various obj' 'Falls, trips, etc.' 'Falls, trips, etc.'
#  'cardio/sync' 'Falls, trips, etc.' 'Other mechanism' 'Other mechanism'
#  'Other mechanism' 'Other mechanism' 'Falls, trips, etc.'
#  'Falls, trips, etc.' 'Hit with various obj' 'Other mechanism'
#  'Multi-sport' 'Falls, trips, etc.' 'Other mechanism' 'Falls, trips, etc.'
#  'Falls, trips, etc.' 'Falls, trips, etc.' 'Falls, trips, etc.']
# ['Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other'
#  'Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other'
#  'Other' 'Other' 'Other' 'Other' 'Other' 'Multi-sport' 'Other' 'Other'
#  'Other' 'Other' 'Other' 'Other']

# %%
#l_list = []
#for txt in text_np:
#    l_list.append( len(txt) )
    
#l_list[0:10]

#max(l_list)

# %%
maxlen = 207
training_samples = 1491
validation_samples = 500
max_words = 100000
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(text_np)
sequences = tokenizer.texts_to_sequences(text_np)

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
data = pad_sequences(sequences, maxlen=maxlen)

print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', train_labels_np.shape)
# Out:
# Found 1857 unique tokens.
# Shape of data tensor: (1991, 207)
# Shape of label tensor: (1991,)

# %%
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
train_labels_np = train_labels_np[indices]
x_train = data[:training_samples]
y_train = train_labels_np[:training_samples]
x_val = data[training_samples: training_samples + validation_samples]
y_val = train_labels_np[training_samples: training_samples + validation_samples]

# %%
label_encoder = LabelEncoder()

y_train_integer_encoded = label_encoder.fit_transform(y_train)
y_val_integer_encoded = label_encoder.fit_transform(y_val)

#y_train_integer_encoded
#y_train_integer_encoded
y_train_one_hot = to_categorical(y_train_integer_encoded, num_classes=7)
y_val_one_hot = to_categorical(y_val_integer_encoded, num_classes=7)

# %%
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense
model = Sequential()
model.add(Embedding(max_words, 8, input_length=maxlen))
model.add(Flatten())
model.add(Dense(7, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 207, 8)            800000
# _________________________________________________________________
# flatten (Flatten)            (None, 1656)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 11599
# =================================================================
# Total params: 811,599
# Trainable params: 811,599
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train_one_hot,
epochs=80,
batch_size=32,
validation_data=(x_val, y_val_one_hot))
# Out:
# Epoch 1/80
# 47/47 [==============================] - 1s 14ms/step - loss: 0.3872 - accuracy: 0.4715 - val_loss: 0.3273 - val_accuracy: 0.4980
# Epoch 2/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.3263 - accuracy: 0.4795 - val_loss: 0.3167 - val_accuracy: 0.4980
# Epoch 3/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.3152 - accuracy: 0.4795 - val_loss: 0.3029 - val_accuracy: 0.4980
# Epoch 4/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2985 - accuracy: 0.4876 - val_loss: 0.2836 - val_accuracy: 0.4980
# Epoch 5/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2775 - accuracy: 0.5272 - val_loss: 0.2658 - val_accuracy: 0.6660
# Epoch 6/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2551 - accuracy: 0.6123 - val_loss: 0.2430 - val_accuracy: 0.6780
# Epoch 7/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2337 - accuracy: 0.6714 - val_loss: 0.2227 - val_accuracy: 0.7380
# Epoch 8/80
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2148 - accuracy: 0.7143 - val_loss: 0.2033 - val_accuracy: 0.7600
# Epoch 9/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1975 - accuracy: 0.7425 - val_loss: 0.1887 - val_accuracy: 0.7800
# Epoch 10/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1829 - accuracy: 0.7639 - val_loss: 0.1787 - val_accuracy: 0.7820
# Epoch 11/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1706 - accuracy: 0.7867 - val_loss: 0.1669 - val_accuracy: 0.7920
# Epoch 12/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1598 - accuracy: 0.7981 - val_loss: 0.1597 - val_accuracy: 0.7980
# Epoch 13/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1503 - accuracy: 0.8149 - val_loss: 0.1529 - val_accuracy: 0.7960
# Epoch 14/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1425 - accuracy: 0.8209 - val_loss: 0.1474 - val_accuracy: 0.8140
# Epoch 15/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1351 - accuracy: 0.8310 - val_loss: 0.1414 - val_accuracy: 0.8140
# Epoch 16/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1285 - accuracy: 0.8397 - val_loss: 0.1368 - val_accuracy: 0.8200
# Epoch 17/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1222 - accuracy: 0.8524 - val_loss: 0.1337 - val_accuracy: 0.8280
# Epoch 18/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1170 - accuracy: 0.8632 - val_loss: 0.1315 - val_accuracy: 0.8340
# Epoch 19/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0
80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.1211 - val_accuracy: 0.8800
# Epoch 76/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.1222 - val_accuracy: 0.8800
# Epoch 77/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0106 - accuracy: 0.9973 - val_loss: 0.1227 - val_accuracy: 0.8800
# Epoch 78/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.1236 - val_accuracy: 0.8780
# Epoch 79/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.1285 - val_accuracy: 0.8760
# Epoch 80/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.1285 - val_accuracy: 0.8780

# %%
modelv2 = Sequential()
modelv2.add(Embedding(max_words, 8, input_length=maxlen))
modelv2.add(Flatten())
modelv2.add(Dense(64, activation='relu'))
modelv2.add(Dense(7, activation='sigmoid'))
modelv2.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
modelv2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 207, 8)            800000
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1656)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                106048
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 906,503
# Trainable params: 906,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2= modelv2.fit(x_train, y_train_one_hot,
epochs=80,
batch_size=32,
validation_data=(x_val, y_val_one_hot))
# Out:
# Epoch 1/80
# 47/47 [==============================] - 1s 12ms/step - loss: 0.3633 - accuracy: 0.4453 - val_loss: 0.3187 - val_accuracy: 0.4980
# Epoch 2/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3097 - accuracy: 0.4930 - val_loss: 0.2885 - val_accuracy: 0.5300
# Epoch 3/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2757 - accuracy: 0.5687 - val_loss: 0.2501 - val_accuracy: 0.6140
# Epoch 4/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2411 - accuracy: 0.6533 - val_loss: 0.2311 - val_accuracy: 0.7400
# Epoch 5/80
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2160 - accuracy: 0.7150 - val_loss: 0.2154 - val_accuracy: 0.7400
# Epoch 6/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1960 - accuracy: 0.7599 - val_loss: 0.1894 - val_accuracy: 0.7700
# Epoch 7/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1775 - accuracy: 0.7780 - val_loss: 0.1751 - val_accuracy: 0.7880
# Epoch 8/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1616 - accuracy: 0.7921 - val_loss: 0.1682 - val_accuracy: 0.8020
# Epoch 9/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1479 - accuracy: 0.8169 - val_loss: 0.1562 - val_accuracy: 0.8080
# Epoch 10/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1351 - accuracy: 0.8283 - val_loss: 0.1496 - val_accuracy: 0.8300
# Epoch 11/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1244 - accuracy: 0.8431 - val_loss: 0.1396 - val_accuracy: 0.8300
# Epoch 12/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1147 - accuracy: 0.8518 - val_loss: 0.1376 - val_accuracy: 0.8220
# Epoch 13/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1054 - accuracy: 0.8719 - val_loss: 0.1309 - val_accuracy: 0.8320
# Epoch 14/80
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0976 - accuracy: 0.8826 - val_loss: 0.1267 - val_accuracy: 0.8440
# Epoch 15/80
# 47/47 [==============================] - 1s 14ms/step - loss: 0.
# 47/47 [==============================] - 0s 9ms/step - loss: 4.3389e-06 - accuracy: 1.0000 - val_loss: 0.3223 - val_accuracy: 0.8620
# Epoch 69/80
# 47/47 [==============================] - 0s 9ms/step - loss: 3.0351e-06 - accuracy: 1.0000 - val_loss: 0.3292 - val_accuracy: 0.8540
# Epoch 70/80
# 47/47 [==============================] - 0s 9ms/step - loss: 2.1550e-06 - accuracy: 1.0000 - val_loss: 0.3350 - val_accuracy: 0.8620
# Epoch 71/80
# 47/47 [==============================] - 0s 9ms/step - loss: 1.6141e-06 - accuracy: 1.0000 - val_loss: 0.3415 - val_accuracy: 0.8560
# Epoch 72/80
# 47/47 [==============================] - 0s 9ms/step - loss: 1.1795e-06 - accuracy: 1.0000 - val_loss: 0.3447 - val_accuracy: 0.8580
# Epoch 73/80
# 47/47 [==============================] - 0s 10ms/step - loss: 8.8581e-07 - accuracy: 1.0000 - val_loss: 0.3530 - val_accuracy: 0.8580
# Epoch 74/80
# 47/47 [==============================] - 0s 10ms/step - loss: 6.7590e-07 - accuracy: 1.0000 - val_loss: 0.3614 - val_accuracy: 0.8600
# Epoch 75/80
# 47/47 [==============================] - 0s 10ms/step - loss: 5.2873e-07 - accuracy: 1.0000 - val_loss: 0.3655 - val_accuracy: 0.8600
# Epoch 76/80
# 47/47 [==============================] - 0s 9ms/step - loss: 4.0834e-07 - accuracy: 1.0000 - val_loss: 0.3739 - val_accuracy: 0.8580
# Epoch 77/80
# 47/47 [==============================] - 0s 9ms/step - loss: 3.3957e-07 - accuracy: 1.0000 - val_loss: 0.3761 - val_accuracy: 0.8580
# Epoch 78/80
# 47/47 [==============================] - 0s 9ms/step - loss: 2.7865e-07 - accuracy: 1.0000 - val_loss: 0.3822 - val_accuracy: 0.8620
# Epoch 79/80
# 47/47 [==============================] - 0s 9ms/step - loss: 2.3055e-07 - accuracy: 1.0000 - val_loss: 0.3844 - val_accuracy: 0.8600
# Epoch 80/80
# 47/47 [==============================] - 0s 9ms/step - loss: 1.9566e-07 - accuracy: 1.0000 - val_loss: 0.3873 - val_accuracy: 0.8560

# %%
model.save_weights('../Model Objects/keras_outv2.h5')

# %%
def getModel():
    my_dim = 8
    
    model = Sequential()
    model.add(Embedding(max_words, my_dim, input_length=maxlen))
    model.add(Flatten())
#    model.add(Dense(32, activation='relu'))
    model.add(Dense(7, activation='softmax'))
    
    return model

# %%
# Different configurations to try
epochs_list = [30, 60, 90]
batch_sizes = [16, 32, 64]
#embedding_dim = 8
# Dictionary to store the history of each configuration
history_dict = {}

for epochs in epochs_list:
    for batch_size in batch_sizes:
        # Get a fresh instance of the model for each run
        model = getModel()

        # Compile the model
        model.compile(optimizer='rmsprop',
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

        # Train the model
        history = model.fit(x_train, y_train_one_hot,
                            epochs=epochs,
                            batch_size=batch_size,
                            validation_data=(x_val, y_val_one_hot),
                            verbose=2)  # Set verbose to 2 for less output

        # Save the history of this configuration
        history_dict[f"epochs_{epochs}_batch_{batch_size}"] = history.history

        # Optionally, you can print out the final validation accuracy for each configuration
        final_val_accuracy = history.history['val_accuracy'][-1]
        print(f"Epochs: {epochs}, Batch size: {batch_size}, Validation accuracy: {final_val_accuracy}")

# Now you can analyze the history_dict to see which configuration performed best

# %%
history_dict
