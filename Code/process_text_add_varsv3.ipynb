# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np

import pandas as pd
import os

# %%
train_path = '../data_to_model/keras_data/model_df_full_narrative.csv'
train_df = pd.read_csv(train_path)
train_df
# Out:
#       cpsc_case_number                                          narrative  \
# 0            100145411  67 yof pt fell on the floor playing pickle bal...
# 1            100417928  63yof playing pickleball in the hot sun and pa...
# 2            100417973       66yom strained lower leg playing pickle ball
# 3            100417997  60yof pt playing pickle ball and fell sustaine...
# 4            100454409  70 yom pt injured knee while playing pickle ba...
# ...                ...                                                ...
# 1986         200101825  68 yof tripped and fell while playing tennis. ...
# 1987         200102934  76yof was hit in the eye with a tennis ball dx...
# 1988         200110467  61yof was playing tennis when she developed pa...
# 1989         200124689  70yof fell while playing tennis dx: strained u...
# 1990         200301553  76yom.playing tennis slipped.fell down.dx.lac....
#
#          primary_mechanism
# 0       Falls, trips, etc.
# 1              Heat stroke
# 2          Other mechanism
# 3       Falls, trips, etc.
# 4          Other mechanism
# ...                    ...
# 1986    Falls, trips, etc.
# 1987  Hit with various obj
# 1988  Undetermined/unknown
# 1989    Falls, trips, etc.
# 1990    Falls, trips, etc.
#
# [1991 rows x 3 columns]

# %%
text_np = np.array(train_df['narrative'])
train_labels_np = np.array(train_df['primary_mechanism'])
train_labels_np_bin = np.where(train_labels_np == 'Multi-sport', 'Multi-sport', 'Other')
print(train_labels_np[0:30])
print(train_labels_np_bin[0:30])
# Out:
# ['Falls, trips, etc.' 'Heat stroke' 'Other mechanism' 'Falls, trips, etc.'
#  'Other mechanism' 'Falls, trips, etc.' 'Falls, trips, etc.'
#  'Other mechanism' 'Other mechanism' 'Falls, trips, etc.'
#  'Hit with various obj' 'Falls, trips, etc.' 'Falls, trips, etc.'
#  'cardio/sync' 'Falls, trips, etc.' 'Other mechanism' 'Other mechanism'
#  'Other mechanism' 'Other mechanism' 'Falls, trips, etc.'
#  'Falls, trips, etc.' 'Hit with various obj' 'Other mechanism'
#  'Multi-sport' 'Falls, trips, etc.' 'Other mechanism' 'Falls, trips, etc.'
#  'Falls, trips, etc.' 'Falls, trips, etc.' 'Falls, trips, etc.']
# ['Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other'
#  'Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other' 'Other'
#  'Other' 'Other' 'Other' 'Other' 'Other' 'Multi-sport' 'Other' 'Other'
#  'Other' 'Other' 'Other' 'Other']

# %%
#l_list = []
#for txt in text_np:
#    l_list.append( len(txt) )
    
#l_list[0:10]

#max(l_list)

# %%
maxlen = 207
training_samples = 1491
validation_samples = 500
max_words = 100000
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(text_np)
sequences = tokenizer.texts_to_sequences(text_np)

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
data = pad_sequences(sequences, maxlen=maxlen)

print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', train_labels_np.shape)
# Out:
# Found 1857 unique tokens.
# Shape of data tensor: (1991, 207)
# Shape of label tensor: (1991,)

# %%
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
train_labels_np = train_labels_np[indices]
x_train = data[:training_samples]
y_train = train_labels_np[:training_samples]
x_val = data[training_samples: training_samples + validation_samples]
y_val = train_labels_np[training_samples: training_samples + validation_samples]

# %%
label_encoder = LabelEncoder()

y_train_integer_encoded = label_encoder.fit_transform(y_train)
y_val_integer_encoded = label_encoder.fit_transform(y_val)

#y_train_integer_encoded
#y_train_integer_encoded
y_train_one_hot = to_categorical(y_train_integer_encoded, num_classes=7)
y_val_one_hot = to_categorical(y_val_integer_encoded, num_classes=7)

# %%
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense
model = Sequential()
model.add(Embedding(max_words, 8, input_length=maxlen))
model.add(Flatten())
model.add(Dense(7, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 207, 8)            800000
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1656)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 11599
# =================================================================
# Total params: 811,599
# Trainable params: 811,599
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train_one_hot,
epochs=80,
batch_size=32,
validation_data=(x_val, y_val_one_hot))
# Out:
# Epoch 1/80
# 47/47 [==============================] - 1s 13ms/step - loss: 0.4024 - accuracy: 0.4668 - val_loss: 0.3197 - val_accuracy: 0.5060
# Epoch 2/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.3256 - accuracy: 0.4769 - val_loss: 0.3069 - val_accuracy: 0.5060
# Epoch 3/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.3111 - accuracy: 0.4863 - val_loss: 0.2924 - val_accuracy: 0.5400
# Epoch 4/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2910 - accuracy: 0.5218 - val_loss: 0.2711 - val_accuracy: 0.5620
# Epoch 5/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2678 - accuracy: 0.5714 - val_loss: 0.2502 - val_accuracy: 0.5840
# Epoch 6/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2461 - accuracy: 0.6278 - val_loss: 0.2338 - val_accuracy: 0.6140
# Epoch 7/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2276 - accuracy: 0.6720 - val_loss: 0.2166 - val_accuracy: 0.7240
# Epoch 8/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2111 - accuracy: 0.7210 - val_loss: 0.2037 - val_accuracy: 0.7380
# Epoch 9/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1973 - accuracy: 0.7438 - val_loss: 0.1934 - val_accuracy: 0.7500
# Epoch 10/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1858 - accuracy: 0.7592 - val_loss: 0.1848 - val_accuracy: 0.7720
# Epoch 11/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1753 - accuracy: 0.7700 - val_loss: 0.1764 - val_accuracy: 0.7720
# Epoch 12/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1663 - accuracy: 0.7834 - val_loss: 0.1708 - val_accuracy: 0.7800
# Epoch 13/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1579 - accuracy: 0.7928 - val_loss: 0.1647 - val_accuracy: 0.7960
# Epoch 14/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1504 - accuracy: 0.8089 - val_loss: 0.1598 - val_accuracy: 0.7980
# Epoch 15/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1434 - accuracy: 0.8156 - val_loss: 0.1550 - val_accuracy: 0.8100
# Epoch 16/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1367 - accuracy: 0.8263 - val_loss: 0.1514 - val_accuracy: 0.8140
# Epoch 17/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1308 - accuracy: 0.8357 - val_loss: 0.1483 - val_accuracy: 0.8100
# Epoch 18/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1252 - accuracy: 0.8424 - val_loss: 0.1447 - val_accuracy: 0.8240
# Epoch 19/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1195 - accuracy: 0.8571 - val_loss: 0.1416 - val_accuracy: 0.8120
# Epoch 20/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0
80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0339 - accuracy: 0.9832 - val_loss: 0.1173 - val_accuracy: 0.8740
# Epoch 49/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0323 - accuracy: 0.9846 - val_loss: 0.1180 - val_accuracy: 0.8780
# Epoch 50/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0309 - accuracy: 0.9852 - val_loss: 0.1185 - val_accuracy: 0.8740
# Epoch 51/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0294 - accuracy: 0.9859 - val_loss: 0.1185 - val_accuracy: 0.8760
# Epoch 52/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0282 - accuracy: 0.9852 - val_loss: 0.1190 - val_accuracy: 0.8760
# Epoch 53/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0269 - accuracy: 0.9866 - val_loss: 0.1189 - val_accuracy: 0.8760
# Epoch 54/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0256 - accuracy: 0.9879 - val_loss: 0.1205 - val_accuracy: 0.8760
# Epoch 55/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0244 - accuracy: 0.9899 - val_loss: 0.1200 - val_accuracy: 0.8740
# Epoch 56/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0233 - accuracy: 0.9913 - val_loss: 0.1204 - val_accuracy: 0.8720
# Epoch 57/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0223 - accuracy: 0.9906 - val_loss: 0.1215 - val_accuracy: 0.8780
# Epoch 58/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0212 - accuracy: 0.9933 - val_loss: 0.1209 - val_accuracy: 0.8760
# Epoch 59/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0201 - accuracy: 0.9933 - val_loss: 0.1226 - val_accuracy: 0.8780
# Epoch 60/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0192 - accuracy: 0.9933 - val_loss: 0.1233 - val_accuracy: 0.8840
# Epoch 61/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0183 - accuracy: 0.9966 - val_loss: 0.1234 - val_accuracy: 0.8820
# Epoch 62/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0174 - accuracy: 0.9960 - val_loss: 0.1238 - val_accuracy: 0.8840
# Epoch 63/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0165 - accuracy: 0.9966 - val_loss: 0.1245 - val_accuracy: 0.8840
# Epoch 64/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0157 - accuracy: 0.9960 - val_loss: 0.1251 - val_accuracy: 0.8760
# Epoch 65/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0149 - accuracy: 0.9960 - val_loss: 0.1261 - val_accuracy: 0.8800
# Epoch 66/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0142 - accuracy: 0.9973 - val_loss: 0.1281 - val_accuracy: 0.8820
# Epoch 67/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0135 - accuracy: 0.9980 - val_loss: 0.1280 - val_accuracy: 0.8820
# Epoch 68/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0128 - accuracy: 0.9980 - val_loss: 0.1275 - val_accuracy: 0.8820
# Epoch 69/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0122 - accuracy: 0.9980 - val_loss: 0.1297 - val_accuracy: 0.8780
# Epoch 70/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0116 - accuracy: 0.9987 - val_loss: 0.1300 - val_accuracy: 0.8780
# Epoch 71/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0110 - accuracy: 0.9987 - val_loss: 0.1303 - val_accuracy: 0.8760
# Epoch 72/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0104 - accuracy: 0.9987 - val_loss: 0.1323 - val_accuracy: 0.8760
# Epoch 73/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0099 - accuracy: 0.9993 - val_loss: 0.1332 - val_accuracy: 0.8800
# Epoch 74/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0094 - accuracy: 0.9987 - val_loss: 0.1341 - val_accuracy: 0.8760
# Epoch 75/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0089 - accuracy: 0.9993 - val_loss: 0.1343 - val_accuracy: 0.8700
# Epoch 76/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0084 - accuracy: 0.9993 - val_loss: 0.1345 - val_accuracy: 0.8820
# Epoch 77/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0080 - accuracy: 0.9993 - val_loss: 0.1362 - val_accuracy: 0.8780
# Epoch 78/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0076 - accuracy: 0.9993 - val_loss: 0.1376 - val_accuracy: 0.8720
# Epoch 79/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0072 - accuracy: 0.9993 - val_loss: 0.1374 - val_accuracy: 0.8740
# Epoch 80/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0068 - accuracy: 0.9993 - val_loss: 0.1400 - val_accuracy: 0.8800

# %%
modelv2 = Sequential()
modelv2.add(Embedding(max_words, 8, input_length=maxlen))
modelv2.add(Flatten())
modelv2.add(Dense(64, activation='relu'))
modelv2.add(Dense(7, activation='sigmoid'))
modelv2.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
modelv2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 207, 8)            800000
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1656)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                106048
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 906,503
# Trainable params: 906,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2= modelv2.fit(x_train, y_train_one_hot,
epochs=80,
batch_size=32,
validation_data=(x_val, y_val_one_hot))
# Out:
# Epoch 1/80
# 47/47 [==============================] - 1s 17ms/step - loss: 0.3662 - accuracy: 0.4688 - val_loss: 0.3125 - val_accuracy: 0.5060
# Epoch 2/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.3163 - accuracy: 0.4816 - val_loss: 0.2921 - val_accuracy: 0.5180
# Epoch 3/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2859 - accuracy: 0.5292 - val_loss: 0.2566 - val_accuracy: 0.6280
# Epoch 4/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2513 - accuracy: 0.6284 - val_loss: 0.2296 - val_accuracy: 0.6540
# Epoch 5/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2242 - accuracy: 0.6821 - val_loss: 0.2076 - val_accuracy: 0.7320
# Epoch 6/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2042 - accuracy: 0.7210 - val_loss: 0.1930 - val_accuracy: 0.7540
# Epoch 7/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1869 - accuracy: 0.7505 - val_loss: 0.1826 - val_accuracy: 0.7880
# Epoch 8/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1726 - accuracy: 0.7713 - val_loss: 0.1702 - val_accuracy: 0.7920
# Epoch 9/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1588 - accuracy: 0.7907 - val_loss: 0.1600 - val_accuracy: 0.7860
# Epoch 10/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1466 - accuracy: 0.8095 - val_loss: 0.1536 - val_accuracy: 0.8080
# Epoch 11/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1354 - accuracy: 0.8270 - val_loss: 0.1455 - val_accuracy: 0.8260
# Epoch 12/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1251 - accuracy: 0.8424 - val_loss: 0.1388 - val_accuracy: 0.8200
# Epoch 13/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1147 - accuracy: 0.8625 - val_loss: 0.1336 - val_accuracy: 0.8260
# Epoch 14/80
# 47/47 [==============================] - 1s 12ms/step - loss: 0.1057 - accuracy: 0.8665 - val_loss: 0.1326 - val_accuracy: 0.8220
# Epoch 15/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0975 - accuracy: 0.8726 - val_loss: 0.1258 - val_accuracy: 0.8380
# Epoch 16/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0887 - accuracy: 0.8907 - val_loss: 0.1257 - val_accuracy: 0.8440
# Epoch 17/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0817 - accuracy: 0.9074 - val_loss: 0.1268 - val_accuracy: 0.8540
# Epoch 18/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0749 - accuracy: 0.9168 - val_loss: 0.1201 - val_accuracy: 0.8560
# Epoch 19/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0683 - accuracy: 0.9329 - val_loss: 0.1188 - val_accuracy: 0.8660
# Epoch 20/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0626 - accuracy: 0.9363 - val_loss: 0.1212 - val_accuracy: 0.8600
# Epoch 21/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0571 - accuracy: 0.9470 - val_loss: 0.1200 - val_accuracy: 0.8540
# Epoch 22/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0519 - accuracy: 0.9504 - val_loss: 0.1191 - val_accuracy: 0.8640
# Epoch 23/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0471 - accuracy: 0.9598 - val_loss: 0.1185 - val_accuracy: 0.8680
# Epoch 24/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0427 - accuracy: 0.9651 - val_loss: 0.1217 - val_accuracy: 0.8640
# Epoch 25/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0389 - accuracy: 0.9645 - val_loss: 0.1220 - val_accuracy: 0.8600
# Epoch 26/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0351 - accuracy: 0.9718 - val_loss: 0.1264 - val_accuracy: 0.8660
# Epoch 27/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0314 - accuracy: 0.9765 - val_loss: 0.1266 - val_accuracy: 0.8720
# Epoch 28/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0284 - accuracy: 0.9812 - val_loss: 0.1251 - val_accuracy: 0.8720
# Epoch 29/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0253 - accuracy: 0.9799 - val_loss: 0.1288 - val_accuracy: 0.8680
# Epoch 30/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0224 - accuracy: 0.9879 - val_loss: 0.1321 - val_accuracy: 0.8660
# Epoch 31/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0200 - accuracy: 0.9873 - val_loss: 0.1389 - val_accuracy: 0.8720
# Epoch 32/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0179 - accuracy: 0.9879 - val_loss: 0.1342 - val_accuracy: 0.8700
# Epoch 33/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0158 - accuracy: 0.9920 - val_loss: 0.1409 - val_accuracy: 0.8700
# Epoch 34/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0136 - accuracy: 0.9953 - val_loss: 0.1435 - val_accuracy: 0.8700
# Epoch 35/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0120 - accuracy: 0.9940 - val_loss: 0.1463 - val_accuracy: 0.8660
# Epoch 36/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0106 - accuracy: 0.9953 - val_loss: 0.1500 - val_accuracy: 0.8720
# Epoch 37/80
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0093 - accuracy: 0.9980 - val_loss: 0.1521 - val_accuracy: 0.8740
# Epoch 38/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.1557 - val_accuracy: 0.8680
# Epoch 39/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 0.9987 - val_loss: 0.1627 - val_accuracy: 0.8700
# Epoch 40/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.1682 - val_accuracy: 0.8780
# Epoch 41/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.1682 - val_accuracy: 0.8740
# Epoch 42/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.1726 - val_accuracy: 0.8780
# Epoch 43/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1745 - val_accuracy: 0.8740
# Epoch 44/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.1806 - val_accuracy: 0.8680
# Epoch 45/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1881 - val_accuracy: 0.8720
# Epoch 46/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.8760
# Epoch 47/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1910 - val_accuracy: 0.8740
# Epoch 48/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.8780
# Epoch 49/80
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0
# 47/47 [==============================] - 0s 8ms/step - loss: 4.8251e-06 - accuracy: 1.0000 - val_loss: 0.3382 - val_accuracy: 0.8800
# Epoch 70/80
# 47/47 [==============================] - 0s 8ms/step - loss: 3.2106e-06 - accuracy: 1.0000 - val_loss: 0.3458 - val_accuracy: 0.8780
# Epoch 71/80
# 47/47 [==============================] - 0s 8ms/step - loss: 2.3884e-06 - accuracy: 1.0000 - val_loss: 0.3530 - val_accuracy: 0.8820
# Epoch 72/80
# 47/47 [==============================] - 0s 8ms/step - loss: 1.8786e-06 - accuracy: 1.0000 - val_loss: 0.3608 - val_accuracy: 0.8820
# Epoch 73/80
# 47/47 [==============================] - 0s 8ms/step - loss: 1.2550e-06 - accuracy: 1.0000 - val_loss: 0.3710 - val_accuracy: 0.8840
# Epoch 74/80
# 47/47 [==============================] - 0s 8ms/step - loss: 9.8503e-07 - accuracy: 1.0000 - val_loss: 0.3732 - val_accuracy: 0.8800
# Epoch 75/80
# 47/47 [==============================] - 0s 8ms/step - loss: 7.9719e-07 - accuracy: 1.0000 - val_loss: 0.3797 - val_accuracy: 0.8840
# Epoch 76/80
# 47/47 [==============================] - 0s 8ms/step - loss: 6.0208e-07 - accuracy: 1.0000 - val_loss: 0.3834 - val_accuracy: 0.8820
# Epoch 77/80
# 47/47 [==============================] - 0s 9ms/step - loss: 4.7723e-07 - accuracy: 1.0000 - val_loss: 0.3890 - val_accuracy: 0.8820
# Epoch 78/80
# 47/47 [==============================] - 0s 9ms/step - loss: 3.8182e-07 - accuracy: 1.0000 - val_loss: 0.3976 - val_accuracy: 0.8860
# Epoch 79/80
# 47/47 [==============================] - 0s 8ms/step - loss: 3.1598e-07 - accuracy: 1.0000 - val_loss: 0.3987 - val_accuracy: 0.8840
# Epoch 80/80
# 47/47 [==============================] - 0s 8ms/step - loss: 2.5448e-07 - accuracy: 1.0000 - val_loss: 0.4095 - val_accuracy: 0.8840

# %%
model.save_weights('../Model Objects/keras_outv2.h5')

# %%
def getModel():
    my_dim = 8
    
    model = Sequential()
    model.add(Embedding(max_words, my_dim, input_length=maxlen))
    model.add(Flatten())
#    model.add(Dense(32, activation='relu'))
    model.add(Dense(7, activation='softmax'))
    
    return model

# %%
# Different configurations to try
epochs_list = [30, 60, 90]
batch_sizes = [16, 32, 64]
#embedding_dim = 8
# Dictionary to store the history of each configuration
history_dict = {}

for epochs in epochs_list:
    for batch_size in batch_sizes:
        # Get a fresh instance of the model for each run
        model = getModel()

        # Compile the model
        model.compile(optimizer='rmsprop',
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

        # Train the model
        history = model.fit(x_train, y_train_one_hot,
                            epochs=epochs,
                            batch_size=batch_size,
                            validation_data=(x_val, y_val_one_hot),
                            verbose=2)  # Set verbose to 2 for less output

        # Save the history of this configuration
        history_dict[f"epochs_{epochs}_batch_{batch_size}"] = history.history

        # Optionally, you can print out the final validation accuracy for each configuration
        final_val_accuracy = history.history['val_accuracy'][-1]
        print(f"Epochs: {epochs}, Batch size: {batch_size}, Validation accuracy: {final_val_accuracy}")

# Now you can analyze the history_dict to see which configuration performed best

# %%
history_dict
